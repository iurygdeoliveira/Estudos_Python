# %% [markdown]
# # Introduction to Decision Tree (DT)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
iris = pd.read_csv('/tmp/iris.csv')

y = iris['Species']
iris = iris.drop(['Species'], axis = 1)
X_train, X_test, y_train, y_test = train_test_split(iris, y, test_size=0.1, random_state=42, 
                                                 stratify=y, shuffle=True)

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(20,10))
tree.plot_tree(model)
# Out:
# [Text(446.4, 498.3, 'X[3] <= 0.8\ngini = 0.667\nsamples = 135\nvalue = [45, 45, 45]'),
#  Text(334.79999999999995, 407.70000000000005, 'gini = 0.0\nsamples = 45\nvalue = [45, 0, 0]'),
#  Text(558.0, 407.70000000000005, 'X[3] <= 1.65\ngini = 0.5\nsamples = 90\nvalue = [0, 45, 45]'),
#  Text(223.2, 317.1, 'X[2] <= 4.95\ngini = 0.12\nsamples = 47\nvalue = [0, 44, 3]'),
#  Text(111.6, 226.5, 'gini = 0.0\nsamples = 43\nvalue = [0, 43, 0]'),
#  Text(334.79999999999995, 226.5, 'X[0] <= 6.15\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(223.2, 135.89999999999998, 'X[2] <= 5.05\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(111.6, 45.299999999999955, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(334.79999999999995, 45.299999999999955, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(446.4, 135.89999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(892.8, 317.1, 'X[2] <= 4.85\ngini = 0.045\nsamples = 43\nvalue = [0, 1, 42]'),
#  Text(781.1999999999999, 226.5, 'X[1] <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(669.5999999999999, 135.89999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(892.8, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(1004.4, 226.5, 'gini = 0.0\nsamples = 39\nvalue = [0, 0, 39]')]

# %%
model.score(X_test, y_test)
# Out:
# 0.8666666666666667
